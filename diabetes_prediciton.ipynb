# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarshsingh171/diabetes_prediction/blob/main/diabetes_prediciton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# diabetes prediction

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
diabetes_data = pd.read_csv('/content/diabetes.csv')

# %%
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = diabetes_data.drop(columns='Outcome',axis=1)
Y = diabetes_data['Outcome']

# %%
print(X)
print(Y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
# standardization

# %%
Scaler = StandardScaler()
standard_data = Scaler.fit_transform(X)

# %%
X=standard_data
Y= diabetes_data['Outcome']

# %%
# train,test and split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,x_train.shape,x_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %%
# training the model

# %%
classifier = svm.SVC(kernel='linear')
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
# model evaluation

# %%
x_train_pred = classifier.predict(x_train)

# %%
train_data_acc = accuracy_score(x_train_pred,y_train)

# %%
print(train_data_acc)
# Out:
# 0.7866449511400652

# %%
x_test_pred = classifier.predict(x_test)

# %%
x_test_acc = accuracy_score(x_test_pred,y_test)

# %%
print(x_test_acc)
# Out:
# 0.7727272727272727

# %%
input_data = (7,196,90,0,0,39.8,0.451,41)
input_data_array = np.asarray(input_data)
input_data_reshape = input_data_array.reshape(1,-1)

# %%
# standar. the input data

# %%
std_data = Scaler.transform(input_data_reshape)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction = classifier.predict(std_data)

# %%
if prediction[0]==0:
  print("no diabetes")
else:
  print("diabetes")
# Out:
# diabetes
